# %%
from tkinter import *
from  tkinter import  ttk
#importing connection
import  mysql.connector
#establishing connection
db = mysql.connector.connect(user='root', password='root123', host='localhost', database='saba_practice')
mycursor = db.cursor()

# %%
mycursor.execute("create table REGISTER(NAME varchar(20), CONTACT varchar(10), EMAIL varchar(20), GENDER varchar(20),CITY varchar(20), STATE varchar(20))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-2-6bdfcb789e5b> in <module>
# ----> 1 mycursor.execute("create table REGISTER(NAME varchar(20), CONTACT varchar(10), EMAIL varchar(20), GENDER varchar(20),CITY varchar(20), STATE varchar(20))")
#       2
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     566
#     567         try:
# --> 568             self._handle_result(self._connection.cmd_query(stmt))
#     569         except errors.InterfaceError:
#     570             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     684             query = query.encode('utf-8')
#     685         try:
# --> 686             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     687         except errors.ProgrammingError as err:
#     688             if err.errno == 3948 and \
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     571             return self._handle_eof(packet)
#     572         elif packet[4] == 255:
# --> 573             raise errors.get_exception(packet)
#     574
#     575         # We have a text result set
#
# ProgrammingError: 1050 (42S01): Table 'register' already exists

# %%
#defining register function
def register():
    #getting form data
    name1=name.get()
    con1=contact.get()
    email1=email.get()
    gen1=gender.get()
    city1=city.get()
    state1=state.get()
    #applying empty validation
    if name1=='' or con1==''or email1=='' or gen1==''or city1==''or state1=='':
        message.set("fill the empty field!!!")
    else:
       # Preparing SQL query to INSERT a record into the database.
       insert_record = (
           "INSERT INTO REG(NAME, CONTACT, EMAIL, GENDER, CITY, STATE)"
           "VALUES (%s, %s, %s, %s, %s, %s)"
       )
       if gen1==1:
        data = (name1, con1,email1,"Male",city1,state1)
       else:
        data = (name1, con1, email1, "Female", city1, state1)
       try:
           #executing the sql command
           mycursor.execute(insert_record,data)
           #commit changes in database
           db.commit()
       except:
           db.rollback()
       message.set("Registered successfully.")

#defining Registrationform function
def Registrationform():
    global reg_screen
    reg_screen = Tk()
    #Setting title of screen
    reg_screen.title("Registration Form")
    #setting height and width of screen
    reg_screen.geometry("300x450")
    #declaring variable
    global  message;
    global name
    global contact
    global email
    global gender
    global city
    global state
    name = StringVar()
    contact = StringVar()
    email = StringVar()
    gender = IntVar()
    city = StringVar()
    state = StringVar()
    message = StringVar()
    #Creating layout of Registration form
    Label(reg_screen,width="300", text="Please Enter Details Below", bg="orange",fg="white").pack()
    #name Label
    Label(reg_screen, text="Name : * ").place(x=20,y=40)
    #name textbox
    Entry(reg_screen, textvariable=name).place(x=90,y=42)
    #contact Label
    Label(reg_screen, text="Contact : * ").place(x=20,y=80)
    #contact textbox
    Entry(reg_screen, textvariable=contact).place(x=90,y=82)

    # email Label
    Label(reg_screen, text="Email : * ").place(x=20, y=120)
    # email textbox
    Entry(reg_screen, textvariable=email).place(x=90, y=122)

    # gender Label
    Label(reg_screen, text="Gender : * ").place(x=20, y=160)
    # gender radiobutton
    Radiobutton(reg_screen,text="Male",variable=gender,value=1).place(x=90,y=162)
    Radiobutton(reg_screen, text="Female", variable=gender, value=2).place(x=150, y=162)

    # city Label
    Label(reg_screen, text="City : * ").place(x=20, y=200)
    # city combobox
    monthchoosen = ttk.Combobox(reg_screen, width=27, textvariable=city)
    monthchoosen['values'] = (' Mumbai',
                              ' Bhopal',
                              ' Patna',
                              ' Indore',
                              ' Nagpur',
                              ' Ahmednagr',
                              ' Pune',
                              ' Latur',
                              ' Beed',)
    monthchoosen.current()
    monthchoosen.place(x=90,y=202)

    # state Label
    Label(reg_screen, text="State * ").place(x=20, y=240)
    # state combobox
    monthchoosen = ttk.Combobox(reg_screen, width=27, textvariable=state)
    monthchoosen['values'] = (' Madhya Pradesh',
                              ' Maharashtra',
                              ' Bihar',
                              ' Punjab',
                              ' Gujrat',
                              ' Rajsthan',)
    monthchoosen.current()
    monthchoosen.place(x=90, y=242)
    #Label for displaying login status[success/failed]
    Label(reg_screen, text="",textvariable=message).place(x=95,y=264)
    #Login button
    Button(reg_screen, text="Register", width=10, height=1, bg="skyblue",command=register).place(x=105,y=300)
    reg_screen.mainloop()
#calling function Registrationform
Registrationform()
